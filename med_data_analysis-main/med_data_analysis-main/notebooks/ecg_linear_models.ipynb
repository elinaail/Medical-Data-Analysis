# %%
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



from scipy.stats import skew, kurtosis
from scipy.signal import welch

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.base import clone
from sklearn.svm import LinearSVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
)

warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_rows", 500)

# %%
df = pd.read_pickle("../datasets/clean_ptbxl_with_ecg_n_diagnostic_superclass.pkl")
df
# Out:
#        ecg_id  patient_id    age  sex  height  weight      device  \
# 1           2     13243.0   19.0    0     NaN    70.0   CS-12   E
# 2           3     20372.0   37.0    1     NaN    69.0   CS-12   E
# 6           7     16193.0   54.0    0     NaN    83.0   CS-12   E
# 9          10      9456.0   22.0    1     NaN    56.0   CS-12   E
# 11         12     11031.0   43.0    1     NaN    44.0   CS-12   E
# ...       ...         ...    ...  ...     ...     ...         ...
# 21791   21830     10520.0   86.0    0     NaN     NaN  AT-60    3
# 21792   21831     11905.0   55.0    1     NaN     NaN  AT-60    3
# 21793   21832      7954.0   63.0    0     NaN     NaN  AT-60    3
# 21795   21834     20703.0  300.0    0     NaN     NaN  AT-60    3
# 21797   21836      8873.0   64.0    1     NaN     NaN  AT-60    3
#
#             recording_date                                             report  \
# 1      1984-11-14 12:55:37                sinusbradykardie sonst normales ekg
# 2      1984-11-15 12:49:10                         sinusrhythmus normales ekg
# 6      1984-11-28 13:32:22  sinusrhythmus linkstyp t abnormal, wahrscheinl...
# 9      1984-12-12 14:12:46                         sinusrhythmus normales ekg
# 11     1984-12-21 08:02:26                sinusbradykardie sonst normales ekg
# ...                    ...                                                ...
# 21791  2001-05-28 07:53:21  sinusrhythmus lagetyp normal periphere nieders...
# 21792  2001-05-28 12:49:25  sinusrhythmus lagetyp normal normales ekg 4.46...
# 21793  2001-05-30 14:14:25  sinusrhythmus linkstyp periphere niederspannun...
# 21795  2001-06-05 11:33:39  sinusrhythmus lagetyp normal qrs(t) abnorm    ...
# 21797  2001-06-09 18:21:49  supraventrikulÄre extrasystole(n) sinusrhythmu...
#
#                                        scp_codes heart_axis  \
# 1                   {'NORM': 80.0, 'SBRAD': 0.0}        NaN
# 2                     {'NORM': 100.0, 'SR': 0.0}        NaN
# 6                     {'NORM': 100.0, 'SR': 0.0}        LAD
# 9                     {'NORM': 100.0, 'SR': 0.0}        NaN
# 11                  {'NORM': 80.0, 'SBRAD': 0.0}        NaN
# ...                                          ...        ...
# 21791                  {'NORM': 50.0, 'SR': 0.0}        MID
# 21792                 {'NORM': 100.0, 'SR': 0.0}        MID
# 21793  {'LAFB': 100.0, 'IVCD': 100.0, 'SR': 0.0}        LAD
# 21795   {'NORM': 100.0, 'ABQRS': 0.0, 'SR': 0.0}        MID
# 21797                 {'NORM': 100.0, 'SR': 0.0}        LAD
#
#       infarction_stadium1 infarction_stadium2  second_opinion  \
# 1                     NaN                 NaN           False
# 2                     NaN                 NaN           False
# 6                     NaN                 NaN           False
# 9                     NaN                 NaN           False
# 11                    NaN                 NaN           False
# ...                   ...                 ...             ...
# 21791                 NaN                 NaN           False
# 21792                 NaN                 NaN           False
# 21793                 NaN                 NaN           False
# 21795      Stadium II-III                 NaN           False
# 21797                 NaN                 NaN           False
#
#        initial_autogenerated_report  validated_by_human extra_beats pacemaker  \
# 1                             False                True         NaN       NaN
# 2                             False                True         NaN       NaN
# 6                             False                True         NaN       NaN
# 9                             False                True         NaN       NaN
# 11                            False                True         NaN       NaN
# ...                             ...                 ...         ...       ...
# 21791                          True                True         NaN       NaN
# 21792                          True                True         NaN       NaN
# 21793                          True                True         NaN       NaN
# 21795                          True                True         NaN       NaN
# 21797                          True                True        SVES       NaN
#
#        strat_fold diagnostic_superclass  \
# 1               2                [NORM]
# 2               5                [NORM]
# 6               7                [NORM]
# 9               9                [NORM]
# 11              8                [NORM]
# ...           ...                   ...
# 21791           1                [NORM]
# 21792           9                [NORM]
# 21793           7                  [CD]
# 21795           4                [NORM]
# 21797           8                [NORM]
#
#                                              ecg_signals
# 1      [[-0.015, 0.12, 0.135, -0.053, -0.075, 0.127, ...
# 2      [[-0.035, -0.07, -0.035, 0.053, 0.0, -0.052, 0...
# 6      [[-0.09, -0.02, 0.07, 0.055, -0.08, 0.025, 0.0...
# 9      [[-0.065, -0.12, -0.055, 0.093, -0.005, -0.087...
# 11     [[0.265, 0.35, 0.085, -0.308, 0.09, 0.217, -0....
# ...                                                  ...
# 21791  [[-0.09, 0.05, 0.14, 0.02, -0.115, 0.095, -0.1...
# 21792  [[-0.06, -0.065, -0.005, 0.063, -0.027, -0.035...
# 21793  [[-0.07, -0.03, 0.04, 0.05, -0.055, 0.005, 0.1...
# 21795  [[-0.035, 0.005, 0.04, 0.015, -0.038, 0.022, 0...
# 21797  [[-0.045, -0.035, 0.01, 0.04, -0.027, -0.012, ...
#
# [12766 rows x 21 columns]

# %%
df['heart_axis'].unique()
# Out:
# array([nan, 'LAD', 'ALAD', 'AXR', 'MID', 'ARAD', 'AXL', 'RAD', 'SAG'],
#       dtype=object)

# %%
df['ecg_signals'].iloc[0]
# Out:
# array([[-0.015,  0.12 ,  0.135, ...,  0.16 ,  0.06 ,  0.065],
#        [-0.015,  0.12 ,  0.135, ...,  0.16 ,  0.06 ,  0.065],
#        [-0.015,  0.12 ,  0.135, ...,  0.16 ,  0.06 ,  0.065],
#        ...,
#        [-0.055,  0.015,  0.07 , ..., -0.215, -0.195, -0.13 ],
#        [-0.055,  0.015,  0.07 , ..., -0.215, -0.195, -0.13 ],
#        [-0.055,  0.015,  0.07 , ..., -0.215, -0.195, -0.13 ]],
#       shape=(5000, 12))

# %%
df.shape
# Out:
# (12766, 21)

# %% [markdown]
# # Доработаем датасет

# %% [markdown]
# Посмотрим на распределение таргетных классов "CD", "HYP", "MI", "NORM", "STTC" основных заболеваний и нормы :

# %%
target_cols = ["CD", "HYP", "MI", "NORM", "STTC"]
class_counts = df[target_cols].sum().sort_values(ascending=False)
plt.bar(class_counts.index, class_counts.values)
plt.xlabel("Class")
plt.ylabel("Number of samples")
plt.title("Class distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 target_cols = ["CD", "HYP", "MI", "NORM", "STTC"]
# ----> 2 class_counts = df[target_cols].sum().sort_values(ascending=False)
#       3 plt.bar(class_counts.index, class_counts.values)
#       4 plt.xlabel("Class")
#
# File ~/dev/mentoring/med_data_analysis/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/dev/mentoring/med_data_analysis/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/dev/mentoring/med_data_analysis/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['CD', 'HYP', 'MI', 'NORM', 'STTC'], dtype='object')] are in the [columns]"

# %% [markdown]
# Видно, что классы болезни/норма несбалансированы.\
# Также у пациентов может одновременно могут быть указаны несколько видов диагнозов "CD", "HYP", "MI","STTC" - их комбинации. Выведем все уникальные значения в столбце diagnostic_superclass

# %%
value_diagnostic_superclass = df['diagnostic_superclass'].value_counts()
percent_diagnoz = df['diagnostic_superclass'].value_counts(normalize=True) * 100
result = pd.DataFrame({
    'Количество': value_diagnostic_superclass,
    'Процент': percent_diagnoz.round(1)
})
print(result)
# Out:
#                        Количество  Процент
# diagnostic_superclass
# [NORM]                       5927     46.4
# [STTC]                       1392     10.9
# [MI]                         1061      8.3
# [CD]                         1008      7.9
# [CD, MI]                      692      5.4
# [STTC, HYP]                   384      3.0
# [HYP]                         355      2.8
# [STTC, MI]                    334      2.6
# [CD, NORM]                    295      2.3
# [CD, STTC]                    273      2.1
# [STTC, MI, HYP]               213      1.7
# [CD, HYP]                     164      1.3
# []                            114      0.9
# [MI, HYP]                      94      0.7
# [CD, MI, STTC]                 79      0.6
# [CD, STTC, HYP]                76      0.6
# [CD, STTC, MI, HYP]            72      0.6
# [CD, STTC, MI]                 58      0.5
# [CD, MI, HYP]                  56      0.4
# [STTC, CD, HYP]                42      0.3
# [STTC, CD, MI, HYP]            30      0.2
# [STTC, NORM]                   24      0.2
# [CD, HYP, STTC]                11      0.1
# [HYP, CD, MI, STTC]             5      0.0
# [CD, NORM, STTC]                3      0.0
# [CD, NORM, HYP]                 2      0.0
# [CD, NORM, HYP, MI]             1      0.0
# [NORM, HYP]                     1      0.0

# %% [markdown]
# Удалим строки, где класс нормы(Norm) сочитается с другими классами. Так как c медицинской точки зрения такого быть не должно, плюс таких строк мало и скорее всего это ошибки.

# %%
mask_bad = ((df["NORM"] == 1) &
           ((df["CD"] == 1) |
            (df["HYP"] == 1) |
            (df["MI"]  == 1) |
           (df["STTC"] == 1)))

df = df.loc[~mask_bad].reset_index(drop=True)

# %%
df.shape
# Out:
# (12311, 16)

# %% [markdown]
# Из всех возможных комбинаций диагнозов для одного объекта(порядок диагнозов не важен) соберем уникальные классы

# %%
mapping = {
    "CD": "C",
    "HYP": "H",
    "MI": "M",
    "STTC": "S",}

def make_combo_class(row):
    letters = "".join(
        mapping[col] 
        for col in ["MI", "HYP", "CD", "STTC"] 
        if row[col] == 1
    )
    if letters == "":
        return "N"   
    return letters

# %%
df["combo_class"] = df.apply(make_combo_class, axis=1)

# %% [markdown]
# Проверим, что получилось

# %%
df.combo_class.nunique()
# Out:
# 16

# %%
df.combo_class.value_counts()
# Out:
# combo_class
# N       5917
# S       1391
# M       1060
# C       1007
# MC       692
# HS       384
# H        354
# MS       334
# CS       273
# MHS      213
# HC       164
# MCS      137
# HCS      128
# MHCS     107
# MH        94
# MHC       56
# Name: count, dtype: int64

# %% [markdown]
# Посмотрим на распределение всех классов после обработки таргетной переменной

# %%
class_counts = df["combo_class"].value_counts().sort_values(ascending=False)
plt.bar(class_counts.index, class_counts.values)
plt.xlabel("combo_class")
plt.ylabel("Количество объектов")
plt.title("Распределение классов combo_class")
plt.show()

# %% [markdown]
# С учетом комплексных классов (из сочетаний диагнозов) дисбаланс стал ещё более выраженным: почти половина наблюдений относится к классу N, тогда как ряд комбинаций встречается менее чем в 1 % случаев. Тем не менее, попробуем сделать мультиклассовую классификацию из всех 16 классов. Постараемся компенсировать дисбаланс на этапе обучения модели (за счёт настроек алгоритма).

# %% [markdown]
# Добавим колонку с числовым кодом для каждого комбо класса (закодируем)

# %%
df["combo_idx"], combo_uniques = pd.factorize(df["combo_class"])
y = df["combo_idx"].values

# %%
code_map = (
    df[["combo_idx", "combo_class"]]
    .drop_duplicates()
    .sort_values("combo_idx")
    .reset_index(drop=True)
)
print(code_map)
# Out:
#     combo_idx combo_class
# 0           0           N
# 1           1           S
# 2           2          MS
# 3           3           C
# 4           4          MC
# 5           5          CS
# 6           6           M
# 7           7           H
# 8           8         MHS
# 9           9        MHCS
# 10         10          HC
# 11         11         MCS
# 12         12          HS
# 13         13         HCS
# 14         14          MH
# 15         15         MHC

# %% [markdown]
# **Описание получившихся классов**
#
# **0 - N**   - Normal ECG
#
# **1 - S**   - ST/T Change
#
# **2 - MS**  - Myocardial Infarction + ST/T Change
#
# **3 - C**   - Conduction Disturbance
#
# **4 - MC**  - Myocardial Infarction + Conduction Disturbance
#
# **5 - CS**  - Conduction Disturbance + ST/T Change
#
# **6 - M**   - Myocardial Infarction
#
# **7 - H**   - Hypertrophy
#
# **8 - MHS** - Myocardial Infarction + Hypertrophy + ST/T Change
#
# **9 - MHCS** - Myocardial Infarction + Hypertrophy + Conduction Disturbance + ST/T Change
#
# **10 - HC**  - Hypertrophy + Conduction Disturbance
#
# **11 - MCS** - Myocardial Infarction + Conduction Disturbance + ST/T Change
#
# **12 - HS**  - Hypertrophy + ST/T Change
#
# **13 - HCS** - Hypertrophy + Conduction Disturbance + ST/T Change
#
# **14 - MH**  - Myocardial Infarction + Hypertrophy
#
# **15 - MHC** - Myocardial Infarction + Hypertrophy + Conduction Disturbance

# %% [markdown]
# Обработаем столбец heart_axis

# %% [markdown]
# Посмотрим на уникальные значения в этом столбце

# %%
heart_axis_unique = df['heart_axis'].nunique()
print(f'Количество уникальных значений столбца heart_axis: {heart_axis_unique}')
# Out:
# Количество уникальных значений столбца heart_axis: 9

# %%
value_heart_axis = df['heart_axis'].value_counts()
print(f'Уникальные значения с их частотой:\n {value_heart_axis}')
# Out:
# Уникальные значения с их частотой:
#  heart_axis
# NO_DATA    6705
# MID        2987
# LAD        1827
# ALAD        530
# RAD          92
# AXL          89
# AXR          42
# ARAD         36
# SAG           3
# Name: count, dtype: int64

# %% [markdown]
# Значения MID и NO_DATA - говорит о нормальном отклонении элекрической оси. Если брать в расчет распределние болен/ не болен, то большая часть с диагнозом NORM, что и подтвеждают данные в столбце heart_axis.\
# Остальные значения связаны уже с отклонением от нормы (напрмер, LAD - это отклонение влево)

# %% [markdown]
# Проверим также на пропуски

# %%
missing_heart_axis = df['heart_axis'].isnull().sum()
print(f'Количество пропусков в столбце heart_axis: {missing_heart_axis}')
# Out:
# Количество пропусков в столбце heart_axis: 0

# %% [markdown]
# Закодируем столбец heart_axis методом One Hot Encoding

# %%
df = pd.get_dummies(df, columns=["heart_axis"], prefix="heart_axis")

# %%
df.head(3)
# Out:
#    ecg_id  patient_id       recording_date   age  sex      height  weight  \
# 0       2     13243.0  1984-11-14 12:55:37  19.0    0  171.116262    70.0
# 1       3     20372.0  1984-11-15 12:49:10  37.0    1  167.893889    69.0
# 2       7     16193.0  1984-11-28 13:32:22  54.0    0  182.063572    83.0
#
#                                          ecg_signals  CD  HYP  MI  NORM  STTC  \
# 0  [[-0.015, 0.12, 0.135, -0.053, -0.075, 0.127, ...   0    0   0     1     0
# 1  [[-0.035, -0.07, -0.035, 0.053, 0.0, -0.052, 0...   0    0   0     1     0
# 2  [[-0.09, -0.02, 0.07, 0.055, -0.08, 0.025, 0.0...   0    0   0     1     0
#
#   diagnostic_superclass  strat_fold combo_class  combo_idx  heart_axis_ALAD  \
# 0                [NORM]           2           N          0            False
# 1                [NORM]           5           N          0            False
# 2                [NORM]           7           N          0            False
#
#    heart_axis_ARAD  heart_axis_AXL  heart_axis_AXR  heart_axis_LAD  \
# 0            False           False           False           False
# 1            False           False           False           False
# 2            False           False           False            True
#
#    heart_axis_MID  heart_axis_NO_DATA  heart_axis_RAD  heart_axis_SAG
# 0           False                True           False           False
# 1           False                True           False           False
# 2           False               False           False           False

# %% [markdown]
# Проверим наличие дубликатов в столбце ecg_id

# %%
dupli_ecg_id = df['ecg_id'].duplicated().sum()
print(f'Наличие дублей по id ЭКГ (сумма таких сигналов): {dupli_ecg_id}')
# Out:
# Наличие дублей по id ЭКГ (сумма таких сигналов): 0

# %% [markdown]
# **Обраблтка ЭКГ сигналов**
# 1. ЭКГ сигналы находятся в формате array.
# 2. У каждого пациента есть сигналы по 12 отведениям, каждое отдельное отведение представлено временным рядом из 5000 точек измерений
# 3. Для генерирования признаков использовался статистический метод, с параметрами как mean, max, min, median, std, разница между max и min, а также  среднеквадратичное значение сигнала
# 4. Для создания медицинских признаков по ЭКГ сигналов используем библиотеки из экосистемы SciPy для научных вычислений

# %%
#Функция для извлечения статистических признаков из массива ЭКГ была сгенерирована с помощью AI
def extract_ecg_features(ecg):
    features = {}
    num_leads = ecg.shape[1]
    
    for lead_idx in range(num_leads):
        lead = ecg[:, lead_idx]
        prefix = f"lead{lead_idx+1}"

        #Базовые статистики
        features[f"{prefix}_mean"] = np.mean(lead)
        features[f"{prefix}_median"] = np.median(lead)
        features[f"{prefix}_std"] = np.std(lead)
        features[f"{prefix}_min"] = np.min(lead)
        features[f"{prefix}_max"] = np.max(lead)
        features[f"{prefix}_range"] = np.max(lead) - np.min(lead)
        features[f"{prefix}_rms"] = np.sqrt(np.mean(lead**2))

        #Форма сигнала
        features[f"{prefix}_skew"] = skew(lead)
        features[f"{prefix}_kurt"] = kurtosis(lead)

        #Энергетические признаки
        features[f"{prefix}_energy"] = np.sum(lead**2)
        features[f"{prefix}_norm_energy"] = np.sum(lead**2) / len(lead)

        #Частотные признаки на основе Welch
        freqs, psd = welch(lead, fs=500)
        features[f"{prefix}_dom_freq"] = freqs[np.argmax(psd)]
        features[f"{prefix}_spec_entropy"] = -np.sum((psd/np.sum(psd)) * np.log(psd/np.sum(psd) + 1e-12))

        #LF/HF диапазоны
        lf_band = (freqs >= 0.04) & (freqs <= 0.15)
        hf_band = (freqs >= 0.15) & (freqs <= 0.40)

        lf_energy = np.sum(psd[lf_band])
        hf_energy = np.sum(psd[hf_band])

        features[f"{prefix}_lf_energy"] = lf_energy
        features[f"{prefix}_hf_energy"] = hf_energy
        features[f"{prefix}_lf_hf_ratio"] = lf_energy / (hf_energy + 1e-6)

    return features

#Сгенерируем признаки для всех пациентов в датасете
feature_rows = []

for idx, row in df.iterrows():
    ecg = row["ecg_signals"]
    feats = extract_ecg_features(ecg)
    feature_rows.append(feats)

ecg_features_df = pd.DataFrame(feature_rows)

print("Размер таблицы признаков:", ecg_features_df.shape)

#Сформируем финальный датафрейм: удалим колонку ecg_signals и добавим новые статистические признаки
df_final = pd.concat(
    [
        df.drop(columns=["ecg_signals"]).reset_index(drop=True),
        ecg_features_df.reset_index(drop=True)
    ],
    axis=1
)

print("Финальный датасет для обучения имеет размер:", df_final.shape)
# Out:
# Размер таблицы признаков: (12311, 192)
# Финальный датасет для обучения имеет размер: (12311, 217)

# %% [markdown]
# *Описание созданных признаков*
#
# 1. Базовые статистические признаки (характеризуют форму и уровень сигнала)
# Для каждого отведения рассчитываются:
#  • среднее значение (mean)
#  • медиана (median)
#  • стандартное отклонение (std)
#  • минимальное (min) и максимальное (max) значения
#  • размах (range)
#  • среднеквадратичное значение (RMS)
#
# 2. Признаки формы распределения
#  • асимметрия (skew)
#  • эксцесс (kurtosis)
#
# 3. Энергетические признаки
#  • суммарная энергия (energy)
#  • нормированная энергия (norm_energy)
#
# 4. Частотные признаки (на основе спектральной плотности Welch)
#  • dominant frequency — частота, на которой сигнал имеет максимум энергии;
#  • spectral entropy — спектральная энтропия, отражает степень хаотичности спектра.
#
# 5. LF/HF показатели
# Рассчитываются мощности в диапазонах:
#  • LF (0.04–0.15 Гц)
#  • HF (0.15–0.40 Гц)
#  • и их отношение LF/HF ratio.

# %% [markdown]
# Разобъем датасет на трэйн тест. Создатели датасета рекомендуют делать это по колонке strat_fold. 1-8 train, 9-10 test

# %%
df_final["strat_fold"] = df_final["strat_fold"].astype(int)

train_mask = df_final["strat_fold"].between(1, 8)
test_mask  = df_final["strat_fold"].between(9, 10)

df_train = df_final[train_mask].copy()
df_test  = df_final[test_mask].copy()

n_train = len(df_train)
n_test = len(df_test)
n_total = n_train + n_test

print(f" Размер TRAIN: {df_train.shape};\n Размер TEST: {df_test.shape}")
print(f"train :  {(n_train / n_total):.2f}")
print(f"test :   {(n_test / n_total):.2f}")
# Out:
#  Размер TRAIN: (9127, 217);
#  Размер TEST: (3184, 217)
# train :  0.74
# test :   0.26

# %% [markdown]
# Проверим, нет ли пересекающихся пациентов между трэйн и тест по столбцу patient_id, чтобы избежать data leak

# %%
train_patients = set(df_train["patient_id"])
test_patients  = set(df_test["patient_id"])

cross_of_train_test = train_patients & test_patients

print(f'Есть ли пересечение множеств TRAIN & TEST : {len(cross_of_train_test)}')
# Out:
# Есть ли пересечение множеств TRAIN & TEST : 0

# %% [markdown]
# Поделим датасет

# %%
base_feats = ["age", "sex", "height", "weight"]

heart_feats = [c for c in df_final.columns if c.startswith("heart_axis_")]

ecg_feats = [c for c in df_final.columns if c.startswith("lead") or c in ["rr_mean", "rr_std", "hr_mean"]]

feature_cols = base_feats + heart_feats + ecg_feats

len(feature_cols)
# Out:
# 205

# %%
df_train.head()
# Out:
#    ecg_id  patient_id       recording_date   age  sex      height  weight  CD  \
# 0       2     13243.0  1984-11-14 12:55:37  19.0    0  171.116262    70.0   0
# 1       3     20372.0  1984-11-15 12:49:10  37.0    1  167.893889    69.0   0
# 2       7     16193.0  1984-11-28 13:32:22  54.0    0  182.063572    83.0   0
# 4      12     11031.0  1984-12-21 08:02:26  43.0    1  162.576546    44.0   0
# 5      14     12925.0  1985-01-10 11:45:19  19.0    1  164.620513    58.0   0
#
#    HYP  MI  NORM  STTC diagnostic_superclass  strat_fold combo_class  \
# 0    0   0     1     0                [NORM]           2           N
# 1    0   0     1     0                [NORM]           5           N
# 2    0   0     1     0                [NORM]           7           N
# 4    0   0     1     0                [NORM]           8           N
# 5    0   0     1     0                [NORM]           7           N
#
#    combo_idx  heart_axis_ALAD  heart_axis_ARAD  heart_axis_AXL  \
# 0          0            False            False           False
# 1          0            False            False           False
# 2          0            False            False           False
# 4          0            False            False           False
# 5          0            False            False           False
#
#    heart_axis_AXR  heart_axis_LAD  heart_axis_MID  heart_axis_NO_DATA  \
# 0           False           False           False                True
# 1           False           False           False                True
# 2           False            True           False               False
# 4           False           False           False                True
# 5           False           False           False                True
#
#    heart_axis_RAD  heart_axis_SAG  lead1_mean  lead1_median  lead1_std  \
# 0           False           False   -0.003573        -0.044   0.130397
# 1           False           False   -0.002780        -0.039   0.121845
# 2           False           False   -0.000643        -0.065   0.255256
# 4           False           False    0.003996        -0.015   0.086015
# 5           False           False   -0.000340        -0.015   0.089874
#
#    lead1_min  lead1_max  lead1_range  lead1_rms  lead1_skew  lead1_kurt  \
# 0     -0.419      0.686        1.105   0.130446    1.991794    4.772568
# 1     -0.160      0.870        1.030   0.121877    3.740817   18.286861
# 2     -0.262      1.698        1.960   0.255257    4.682763   23.422237
# 4     -0.132      0.615        0.747   0.086108    2.938560   12.873589
# 5     -0.265      0.560        0.825   0.089874    2.460487    9.930576
#
#    lead1_energy  lead1_norm_energy  lead1_dom_freq  lead1_spec_entropy  \
# 0            2.629579              0.0              0.0                0.0
# 1            2.350857              0.0              0.0                0.0
# 2            2.696565              0.0              0.0                0.0
# 4            2.148947              0.0              0.0                0.0
# 5            2.789035              0.0              0.0                0.0
#
#    lead7_mean  lead7_median  lead7_std  lead7_min  lead7_max  lead7_range  \
# 0    0.004484         0.030   0.219239     -1.918      0.340        2.258
# 1   -0.000299         0.018   0.116498     -0.784      0.162        0.946
# 2   -0.001504         0.030   0.149127     -0.970      0.190        1.160
# 4    0.001293         0.025   0.140496     -1.070      0.330        1.400
# 5    0.004633         0.015   0.139487     -0.955      0.282        1.237
#
#    lead7_rms  lead7_skew  lead7_kurt  lead7_energy  lead7_norm_energy  \
# 0   0.219285   -4.560359   27.186936    240.428483           0.048086
# 1   0.116499   -3.772980   18.275066     67.859783           0.013572
# 2   0.149135   -4.701067   23.123446    111.206230           0.022241
# 4   0.140502   -4.721727   26.656564     98.704030           0.019741
# 5   0.139564   -3.249443   15.257148     97.390680           0.019478
#
#    lead7_dom_freq  lead7_spec_entropy  lead7_lf_energy  lead7_hf_energy  \
# 0         3.90625            2.425722              0.0              0.0
# 1         3.90625            2.565824              0.0              0.0
# 2         3.90625            2.416876              0.0              0.0
# 4         3.90625            2.518219              0.0              0.0
# 5         3.90625            2.584376              0.0              0.0
#
#    lead7_lf_hf_ratio  lead8_mean  lead8_median  lead8_std  lead8_min  \
# 0                0.0    0.012612        0.0185   0.422281     -3.335
# 1                0.0    0.000527        0.0200   0.147836     -1.140
# 2                0.0    0.000161        0.0050   0.203876     -1.234
# 4                0.0   -0.002706       -0.0050   0.219695     -1.435
# 5                0.0   -0.000909        0.0200   0.222731     -1.465
#
#    lead8_max  lead8_range  lead8_rms  lead8_skew  lead8_kurt  lead8_energy  \
# 0      0.966        4.301   0.422470   -4.155571   25.002454    892.402444
# 1      0.346        1.486   0.147837   -4.507868   26.852906    109.278519
# 2      0.454        1.688   0.203876   -2.637436   11.656557    207.827995
# 4      0.505        1.940   0.219711   -3.589362   18.546656    241.365347
# 5      0.543        2.008   0.222733   -3.614324   17.072975    248.049615
#
#    lead8_norm_energy  lead8_dom_freq  lead8_spec_entropy  lead8_lf_energy  \
# 0           0.178480        1.953125            2.343320              0.0
# 1           0.021856        1.953125            2.807185              0.0
# 2           0.041566        1.953125            2.361498              0.0
# 4           0.048273        1.953125            2.414989              0.0
# 5           0.049610        1.953125            2.677246              0.0
#
#    lead8_hf_energy  lead8_lf_hf_ratio  lead9_mean  lead9_median  lead9_std  \
# 0              0.0                0.0    0.012074        -0.015   0.357462
# 1              0.0                0.0   -0.003110        -0.025   0.167441
# 2              0.0                0.0   -0.003219        -0.010   0.212923
# 4              0.0                0.0   -0.008585        -0.074   0.192298
# 5              0.0                0.0   -0.004774        -0.040   0.116826
#
#    lead9_min  lead9_max  lead9_range  lead9_rms  lead9_skew  lead9_kurt  \
# 0     -2.327      1.016        3.343   0.357666   -2.305492   13.818850
# 1     -0.938      0.962        1.900   0.167470    0.667866    9.942672
# 2     -1.427      0.848        2.275   0.212947   -2.365671   12.992250
# 4     -0.749      0.730        1.479   0.192490    1.520290    3.243473
# 5     -0.392      0.659        1.051   0.116923    1.817790    6.007884
#
#    lead9_energy  lead9_norm_energy  lead9_dom_freq  lead9_spec_entropy  \
# 0    639.624532           0.127925        1.953125            2.217202
# 1    140.231537           0.028046        1.953125            2.954122
# 2    226.732292           0.045346        1.953125            2.489647
# 4    185.261958           0.037052        1.953125            2.191167
# 5     68.355423           0.013671        3.906250            2.670991
#
#    lead9_lf_energy  lead9_hf_energy  lead9_lf_hf_ratio  lead10_mean  \
# 0              0.0              0.0                0.0     0.000951
# 1              0.0              0.0                0.0     0.000298
# 2              0.0              0.0                0.0    -0.003809
# 4              0.0              0.0                0.0    -0.004859
# 5              0.0              0.0                0.0    -0.003115
#
#    lead10_median  lead10_std  lead10_min  lead10_max  lead10_range  \
# 0         -0.065    0.274955      -1.115       2.356         3.471
# 1         -0.025    0.140514      -0.353       1.204         1.557
# 2         -0.015    0.203888      -1.252       1.085         2.337
# 4         -0.060    0.169196      -0.229       1.204         1.433
# 5         -0.045    0.161240      -0.315       1.032         1.347
#
#    lead10_rms  lead10_skew  lead10_kurt  lead10_energy  lead10_norm_energy  \
# 0    0.274957     3.638166    23.086402     378.006773            0.075601
# 1    0.140514     4.071041    23.050688      98.721143            0.019744
# 2    0.203924    -0.746935    15.623193     207.924356            0.041585
# 4    0.169266     3.308678    13.810976     143.254694            0.028651
# 5    0.161270     3.373243    15.398727     130.039857            0.026008
#
#    lead10_dom_freq  lead10_spec_entropy  lead10_lf_energy  lead10_hf_energy  \
# 0         1.953125             2.968274               0.0               0.0
# 1         7.812500             2.861704               0.0               0.0
# 2         9.765625             2.586439               0.0               0.0
# 4         1.953125             2.495261               0.0               0.0
# 5         3.906250             2.719876               0.0               0.0
#
#    lead10_lf_hf_ratio  lead11_mean  lead11_median  lead11_std  lead11_min  \
# 0                 0.0     0.003123         -0.040    0.221472      -0.412
# 1                 0.0     0.005196         -0.014    0.111067      -0.166
# 2                 0.0    -0.001781         -0.025    0.224182      -1.016
# 4                 0.0    -0.003210         -0.045    0.162302      -0.168
# 5                 0.0    -0.001872         -0.035    0.153034      -0.253
#
#    lead11_max  lead11_range  lead11_rms  lead11_skew  lead11_kurt  \
# 0       1.927         2.339    0.221494     4.773600    30.799271
# 1       0.981         1.147    0.111188     3.987509    22.280722
# 2       1.493         2.509    0.224190     3.067809    21.965603
# 4       1.222         1.390    0.162333     3.657957    17.734619
# 5       1.005         1.258    0.153045     3.602826    17.027912
#
#    lead11_energy  lead11_norm_energy  lead11_dom_freq  lead11_spec_entropy  \
# 0     245.298383            0.049060         3.906250             2.809712
# 1      61.814393            0.012363         7.812500             2.785814
# 2     251.304823            0.050261        13.671875             2.629124
# 4     131.760602            0.026352         1.953125             2.495108
# 5     117.114428            0.023423         3.906250             2.732033
#
#    lead11_lf_energy  lead11_hf_energy  lead11_lf_hf_ratio  lead12_mean  \
# 0               0.0               0.0                 0.0     0.000392
# 1               0.0               0.0                 0.0     0.004353
# 2               0.0               0.0                 0.0     0.001806
# 4               0.0               0.0                 0.0    -0.000939
# 5               0.0               0.0                 0.0    -0.001972
#
#    lead12_median  lead12_std  lead12_min  lead12_max  lead12_range  \
# 0        -0.0245    0.179950      -0.240       1.558         1.798
# 1        -0.0140    0.101361      -0.130       0.844         0.974
# 2        -0.0150    0.207915      -0.648       1.560         2.208
# 4         0.0050    0.175749      -0.271       1.120         1.391
# 5        -0.0450    0.135272      -0.170       0.970         1.140
#
#    lead12_rms  lead12_skew  lead12_kurt  lead12_energy  lead12_norm_energy  \
# 0    0.179950     4.355631    26.681197     161.910453            0.032382
# 1    0.101454     3.086953    15.452345      51.464647            0.010293
# 2    0.207923     4.628532    28.290579     216.160126            0.043232
# 4    0.175752     1.593869     5.986692     154.443188            0.030889
# 5    0.135286     3.631649    17.307674      91.511955            0.018302
#
#    lead12_dom_freq  lead12_spec_entropy  lead12_lf_energy  lead12_hf_energy  \
# 0         3.906250             2.700164               0.0               0.0
# 1         3.906250             2.691585               0.0               0.0
# 2         7.812500             2.651418               0.0               0.0
# 4         1.953125             2.432506               0.0               0.0
# 5         3.906250             2.733701               0.0               0.0
#
#    lead12_lf_hf_ratio
# 0                 0.0
# 1                 0.0
# 2                 0.0
# 4                 0.0
# 5                 0.0

# %%
X_train = df_train[feature_cols]
y_train = df_train["combo_idx"]


X_test  = df_test[feature_cols]
y_test  = df_test["combo_idx"]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (9127, 205) (9127,)
# (3184, 205) (3184,)

# %%
diag_cols = ["CD", "HYP", "MI", "NORM", "STTC"]

# %%
X_train
# Out:
#         age  sex      height     weight  heart_axis_ALAD  heart_axis_ARAD  \
# 0      19.0    0  171.116262  70.000000            False            False
# 1      37.0    1  167.893889  69.000000            False            False
# 2      54.0    0  182.063572  83.000000            False            False
# 4      43.0    1  162.576546  44.000000            False            False
# 5      19.0    1  164.620513  58.000000            False            False
# ...     ...  ...         ...        ...              ...              ...
# 12305  79.0    1  160.273066  79.617418            False            False
# 12306  86.0    0  166.941744  86.053314            False            False
# 12308  63.0    0  181.949989  79.369158            False            False
# 12309  98.0    0  177.994169  93.194087            False            False
# 12310  64.0    1  165.367448  66.967921            False            False
#
#        heart_axis_AXL  heart_axis_AXR  heart_axis_LAD  heart_axis_MID  \
# 0               False           False           False           False
# 1               False           False           False           False
# 2               False           False            True           False
# 4               False           False           False           False
# 5               False           False           False           False
# ...               ...             ...             ...             ...
# 12305           False           False            True           False
# 12306           False           False           False            True
# 12308           False           False            True           False
# 12309           False           False           False            True
# 12310           False           False            True           False
#
#        heart_axis_NO_DATA  heart_axis_RAD  heart_axis_SAG  lead1_mean  \
# 0                    True           False           False   -0.003573
# 1                    True           False           False   -0.002780
# 2                   False           False           False   -0.000643
# 4                    True           False           False    0.003996
# 5                    True           False           False   -0.000340
# ...                   ...             ...             ...         ...
# 12305               False           False           False    0.000990
# 12306               False           False           False    0.000017
# 12308               False           False           False   -0.002948
# 12309               False           False           False   -0.003086
# 12310               False           False           False   -0.001118
#
#        lead1_median  lead1_std  lead1_min  lead1_max  lead1_range  lead1_rms  \
# 2         207.924356            0.041585         9.765625
# 4         143.254694            0.028651         1.953125
# 5         130.039857            0.026008         3.906250
# ...              ...                 ...              ...
# 12305     332.687709            0.066538         1.953125
# 12306     788.397496            0.157679         3.906250
# 12308     413.471662            0.082694         1.953125
# 12309     183.182766            0.036637         9.765625
# 12310     213.160014            0.042632        13.671875
#
#        lead10_spec_entropy  lead10_lf_energy  lead10_hf_energy  \
# 0                 2.968274               0.0               0.0
# 1                 2.861704               0.0               0.0
# 2                 2.586439               0.0               0.0
# 4                 2.495261               0.0               0.0
# 5                 2.719876               0.0               0.0
# ...                    ...               ...               ...
# 12305             2.175704               0.0               0.0
# 12306             2.848804               0.0               0.0
# 12308             2.066760               0.0               0.0
# 12309             2.904684               0.0               0.0
# 12310             2.829595               0.0               0.0
#
#        lead10_lf_hf_ratio  lead11_mean  lead11_median  lead11_std  lead11_min  \
# 0                     0.0     0.003123         -0.040    0.221472      -0.412
# 1                     0.0     0.005196         -0.014    0.111067      -0.166
# 2                     0.0    -0.001781         -0.025    0.224182      -1.016
# 4                     0.0    -0.003210         -0.045    0.162302      -0.168
# 5                     0.0    -0.001872         -0.035    0.153034      -0.253
# ...                   ...          ...            ...         ...         ...
# 12305                 0.0     0.001548         -0.015    0.227344      -0.650
# 12306                 0.0    -0.000563         -0.080    0.286504      -0.460
# 12308                 0.0    -0.000763         -0.015    0.112325      -0.131
# 12309                 0.0    -0.004051         -0.035    0.176143      -0.535
# 12310                 0.0    -0.000701         -0.030    0.167016      -0.635
#
#        lead11_max  lead11_range  lead11_rms  lead11_skew  lead11_kurt  \
# 0           1.927         2.339    0.221494     4.773600    30.799271
# 1           0.981         1.147    0.111188     3.987509    22.280722
# 2           1.493         2.509    0.224190     3.067809    21.965603
# 4           1.222         1.390    0.162333     3.657957    17.734619
# 5           1.005         1.258    0.153045     3.602826    17.027912
# ...           ...           ...         ...          ...          ...
# 12305       1.690         2.340    0.227349     2.717533    14.806237
# 12306       2.264         2.724    0.286504     4.709692    27.353821
# 12308       0.430         0.561    0.112328     1.909907     3.600411
# 12309       1.484         2.019    0.176189     3.979361    26.778260
# 12310       1.058         1.693    0.167017     2.264234    12.308424
#
#        lead11_energy  lead11_norm_energy  lead11_dom_freq  \
# 0         245.298383            0.049060         3.906250
# 1          61.814393            0.012363         7.812500
# 2         251.304823            0.050261        13.671875
# 4         131.760602            0.026352         1.953125
# 5         117.114428            0.023423         3.906250
# ...              ...                 ...              ...
# 12305     258.437652            0.051688         1.953125
# 12306     410.424018            0.082085         3.906250
# 12308      63.087448            0.012617         1.953125
# 12309     155.213507            0.031043         9.765625
# 12310     139.474006            0.027895         3.906250
#
#        lead11_spec_entropy  lead11_lf_energy  lead11_hf_energy  \
# 0                 2.809712               0.0               0.0
# 1                 2.785814               0.0               0.0
# 2                 2.629124               0.0               0.0
# 4                 2.495108               0.0               0.0
# 5                 2.732033               0.0               0.0
# ...                    ...               ...               ...
# 12305             2.147845               0.0               0.0
# 12306             2.831940               0.0               0.0
# 12308             1.756967               0.0               0.0
# 12309             2.897188               0.0               0.0
# 12310             2.847702               0.0               0.0
#
#        lead11_lf_hf_ratio  lead12_mean  lead12_median  lead12_std  lead12_min  \
# 0                     0.0     0.000392        -0.0245    0.179950      -0.240
# 1                     0.0     0.004353        -0.0140    0.101361      -0.130
# 2                     0.0     0.001806        -0.0150    0.207915      -0.648
# 4                     0.0    -0.000939         0.0050    0.175749      -0.271
# 5                     0.0    -0.001972        -0.0450    0.135272      -0.170
# ...                   ...          ...            ...         ...         ...
# 12305                 0.0    -0.000109        -0.0070    0.165609      -0.495
# 12306                 0.0    -0.002106        -0.0510    0.183398      -0.290
# 12308                 0.0    -0.002707        -0.0290    0.164431      -0.185
# 12309                 0.0    -0.003289        -0.0440    0.140497      -0.220
# 12310                 0.0     0.000209        -0.0260    0.124789      -0.247
#
#        lead12_max  lead12_range  lead12_rms  lead12_skew  lead12_kurt  \
# 0           1.558         1.798    0.179950     4.355631    26.681197
# 1           0.844         0.974    0.101454     3.086953    15.452345
# 2           1.560         2.208    0.207923     4.628532    28.290579
# 4           1.120         1.391    0.175752     1.593869     5.986692
# 5           0.970         1.140    0.135286     3.631649    17.307674
# ...           ...           ...         ...          ...          ...
# 12305       1.224         1.719    0.165609     2.679120    15.495603
# 12306       1.462         1.752    0.183410     4.312642    23.659438
# 12308       0.595         0.780    0.164453     2.141004     4.200388
# 12309       1.125         1.345    0.140536     4.774681    27.984245
# 12310       0.850         1.097    0.124789     3.271671    14.681600
#
#        lead12_energy  lead12_norm_energy  lead12_dom_freq  \
# 0         161.910453            0.032382         3.906250
# 1          51.464647            0.010293         3.906250
# 2         216.160126            0.043232         7.812500
# 4         154.443188            0.030889         1.953125
# 5          91.511955            0.018302         3.906250
# ...              ...                 ...              ...
# 12305     137.131827            0.027426         1.953125
# 12306     168.196251            0.033639         3.906250
# 12308     135.224211            0.027045         1.953125
# 12309      98.751653            0.019750         3.906250
# 12310      77.862082            0.015572         3.906250
#
#        lead12_spec_entropy  lead12_lf_energy  lead12_hf_energy  \
# 0                 2.700164               0.0               0.0
# 1                 2.691585               0.0               0.0
# 2                 2.651418               0.0               0.0
# 4                 2.432506               0.0               0.0
# 5                 2.733701               0.0               0.0
# ...                    ...               ...               ...
# 12305             2.043887               0.0               0.0
# 12306             2.688573               0.0               0.0
# 12308             1.679574               0.0               0.0
# 12309             2.799160               0.0               0.0
# 12310             2.750249               0.0               0.0
#
#        lead12_lf_hf_ratio
# 0                     0.0
# 1                     0.0
# 2                     0.0
# 4                     0.0
# 5                     0.0
# ...                   ...
# 12305                 0.0
# 12306                 0.0
# 12308                 0.0
# 12309                 0.0
# 12310                 0.0
#
# [9127 rows x 205 columns]

# %%
y_train.head(20)
# Out:
# 0     0
# 1     0
# 2     0
# 4     0
# 5     0
# 6     0
# 7     0
# 8     1
# 9     0
# 10    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 20    0
# 21    0
# 22    0
# 23    0
# 24    3
# Name: combo_idx, dtype: int64

# %%
y_train.head(100)
# Out:
# 0       0
# 1       0
# 2       0
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       0
# 10      0
# 12      0
# 13      0
# 14      0
# 15      0
# 16      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      3
# 25      0
# 26      1
# 27      0
# 29      0
# 30      0
# 32      0
# 34      0
# 35      0
# 36      0
# 37      0
# 38      0
# 39      0
# 40      4
# 41      0
# 43      0
# 44      0
# 45      0
# 46      0
# 47      0
# 49      0
# 50      0
# 51      0
# 52      0
# 53      5
# 54      4
# 55      0
# 56      0
# 57      0
# 58      0
# 59      0
# 61      0
# 62      0
# 63      0
# 65      0
# 66      0
# 67      0
# 69      6
# 72      0
# 73      7
# 74      8
# 75      0
# 76      1
# 77      0
# 81      0
# 83      0
# 84      0
# 86      6
# 88      0
# 89      0
# 91      1
# 94      0
# 95      6
# 97      4
# 98      0
# 99      0
# 101     3
# 102    10
# 103     3
# 105     0
# 106     0
# 112     0
# 113     0
# 115     5
# 116     0
# 117     0
# 121     3
# 122     0
# 123    10
# 125     0
# 126     0
# 127     3
# 128     0
# 130     0
# 131     0
# 132     0
# 136     0
# 137     0
# 138     0
# 139     0
# 140     0
# Name: combo_idx, dtype: int64

# %% [markdown]
# # Мультиклассификация

# %%
models = {
    "LogisticRegression_OvR": Pipeline([
        ("scaler", StandardScaler()),
        ("clf", OneVsRestClassifier(
            LogisticRegression(
                max_iter=1000,
                class_weight="balanced",
                random_state=42
            )
        ))
    ]),
    "LinearSVC_OvR": Pipeline([
        ("scaler", StandardScaler()),
        ("clf", OneVsRestClassifier(
            LinearSVC(
                class_weight="balanced",
                random_state=42
            )
        ))
    ]),
    "SGD_log_loss_OvR": Pipeline([
        ("scaler", StandardScaler()),
        ("clf", OneVsRestClassifier(
            SGDClassifier(
                loss="log_loss",
                max_iter=2000,
                class_weight="balanced",
                random_state=42
            )
        ))
    ])
}

# %%
results = []

for name, model in models.items():
    print(f"Модель: {name}")

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    actual_labels = sorted(np.unique(np.concatenate([y_train, y_test, y_pred])))
    print(f"Количество классов: {len(actual_labels)}")

    accuracy = accuracy_score(y_test, y_pred)
    
    prec_micro = precision_score(y_test, y_pred, average="micro", zero_division=0)
    rec_micro = recall_score(y_test, y_pred, average="micro", zero_division=0)
    f1_micro = f1_score(y_test, y_pred, average="micro", zero_division=0)
    
    prec_macro = precision_score(y_test, y_pred, average="macro", zero_division=0)
    rec_macro = recall_score(y_test, y_pred, average="macro", zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average="macro", zero_division=0)
    
    prec_weighted = precision_score(y_test, y_pred, average="weighted", zero_division=0)
    rec_weighted = recall_score(y_test, y_pred, average="weighted", zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average="weighted", zero_division=0)

    print(f"Accuracy:           {accuracy:.3f}")
    print(f"F1-micro:           {f1_micro:.3f}")
    print(f"F1-macro:           {f1_macro:.3f}")
    print(f"F1-weighted:        {f1_weighted:.3f}")
    print(f"Precision-micro:    {prec_micro:.3f}")
    print(f"Recall-micro:       {rec_micro:.3f}")

    print("\nClassification report:")
    print(classification_report(y_test, y_pred, 
                                labels=actual_labels,
                                zero_division=0,
                                digits=3))

    results.append({
        "model": name,
        "accuracy": accuracy,
        "f1_micro": f1_micro,
        "f1_macro": f1_macro,
        "f1_weighted": f1_weighted,
        "prec_micro": prec_micro,
        "rec_micro": rec_micro,
        "prec_macro": prec_macro,
        "rec_macro": rec_macro,
        "num_classes": len(actual_labels)
    })

results_df = pd.DataFrame(results)
print("ИТОГОВАЯ ТАБЛИЦА (сортировка по F1-macro)")
print(results_df.sort_values("f1_macro", ascending=False).round(4))
# Out:
# Модель: LogisticRegression_OvR
# Количество классов: 16
# Accuracy:           0.446
# F1-micro:           0.446
# F1-macro:           0.212
# F1-weighted:        0.479
# Precision-micro:    0.446
# Recall-micro:       0.446
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.841     0.703     0.766      1396
#            1      0.420     0.349     0.381       370
#            2      0.123     0.212     0.156        99
#            3      0.396     0.246     0.304       272
#            4      0.292     0.179     0.222       196
#            5      0.089     0.215     0.126        65
#            6      0.335     0.204     0.253       339
#            7      0.253     0.380     0.304       100
#            8      0.147     0.242     0.183        62
#            9      0.103     0.269     0.149        26
#           10      0.030     0.093     0.045        43
#           11      0.048     0.171     0.075        35
#           12      0.196     0.206     0.201       107
#           13      0.068     0.172     0.098        29
#           14      0.072     0.167     0.101        30
#           15      0.019     0.067     0.029        15
#
#     accuracy                          0.446      3184
#    macro avg      0.215     0.242     0.212      3184
# weighted avg      0.531     0.446     0.479      3184
#
# Модель: LinearSVC_OvR
# Количество классов: 16
# Accuracy:           0.520
# F1-micro:           0.520
# F1-macro:           0.223
# F1-weighted:        0.518
# Precision-micro:    0.520
# Recall-micro:       0.520
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.809     0.764     0.786      1396
#            1      0.412     0.578     0.481       370
#            2      0.091     0.111     0.100        99
#            3      0.389     0.379     0.384       272
#            4      0.319     0.342     0.330       196
#            5      0.189     0.154     0.169        65
#            6      0.295     0.319     0.306       339
#            7      0.292     0.280     0.286       100
#            8      0.230     0.226     0.228        62
#            9      0.083     0.038     0.053        26
#           10      0.200     0.023     0.042        43
#           11      0.045     0.029     0.035        35
#           12      0.294     0.299     0.296       107
#           13      0.000     0.000     0.000        29
#           14      0.000     0.000     0.000        30
#           15      0.077     0.067     0.071        15
#
#     accuracy                          0.520      3184
#    macro avg      0.233     0.225     0.223      3184
# weighted avg      0.521     0.520     0.518      3184
#
# Модель: SGD_log_loss_OvR
# Количество классов: 16
# Accuracy:           0.189
# F1-micro:           0.189
# F1-macro:           0.097
# F1-weighted:        0.241
# Precision-micro:    0.189
# Recall-micro:       0.189
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.857     0.309     0.455      1396
#            1      0.172     0.070     0.100       370
#            2      0.096     0.121     0.107        99
#            3      0.074     0.059     0.066       272
#            4      0.170     0.041     0.066       196
#            5      0.045     0.169     0.071        65
#            6      0.279     0.035     0.063       339
#            7      0.082     0.240     0.122       100
#            8      0.045     0.032     0.038        62
#            9      0.075     0.308     0.121        26
#           10      0.037     0.326     0.067        43
#           11      0.045     0.343     0.080        35
#           12      0.023     0.009     0.013       107
#           13      0.039     0.172     0.064        29
#           14      0.022     0.267     0.041        30
#           15      0.041     0.667     0.078        15
#
#     accuracy                          0.189      3184
#    macro avg      0.132     0.198     0.097      3184
# weighted avg      0.453     0.189     0.241      3184
#
# ИТОГОВАЯ ТАБЛИЦА (сортировка по F1-macro)
#                     model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 1           LinearSVC_OvR    0.5204    0.5204    0.2229       0.5177
# 0  LogisticRegression_OvR    0.4460    0.4460    0.2120       0.4786
# 2        SGD_log_loss_OvR    0.1888    0.1888    0.0970       0.2412
#
#    prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 1      0.5204     0.5204      0.2327     0.2255           16
# 0      0.4460     0.4460      0.2146     0.2422           16
# 2      0.1888     0.1888      0.1316     0.1980           16

# %% [markdown]
# Все модели страдают от сильного дисбаланса классов: F1-macro (0.09-0.21) значительно ниже F1-weighted (0.24-0.48)
#
# Модели хорошо предсказывают только крупные классы (0, 1)
#
# Мелкие классы (9-15) почти не предсказываются (f1 < 0.13)

# %% [markdown]
# # One vs Rest подход

# %% [markdown]
# Поскольку дисбаланс комбенированных классов очень велик, попробуем упростить задачу до бинарной классификации. Будем считать класс 0 — NORM (отсутствие патологий), а все случаи с любыми заболеваниями (любой не-N класс) объединим в класс 1 - PATHOLOGY.

# %%
y_train_bin = (y_train != 0).astype(int)
y_test_bin  = (y_test  != 0).astype(int)

# %%
y_train_bin.value_counts()
# Out:
# combo_idx
# 1    4606
# 0    4521
# Name: count, dtype: int64

# %%
y_test_bin.value_counts()
# Out:
# combo_idx
# 1    1788
# 0    1396
# Name: count, dtype: int64

# %%
ovr_results = []

for name, base_model in models.items():
    print(f"\nМодель: OVR_{name}")
    
    model = clone(base_model)
    
    ovr_pipeline = Pipeline([
        ("scaler", StandardScaler()),
        ("clf", OneVsRestClassifier(model.named_steps['clf']))
    ])

    ovr_pipeline.fit(X_train, y_train_bin) 
    y_pred = ovr_pipeline.predict(X_test)    
    
    actual_labels = sorted(np.unique(np.concatenate([y_train_bin, y_test_bin, y_pred])))
    print(f"Количество классов: {len(actual_labels)}")

    accuracy = accuracy_score(y_test_bin, y_pred)  
    
    prec_micro = precision_score(y_test_bin, y_pred, average="micro", zero_division=0)
    rec_micro = recall_score(y_test_bin, y_pred, average="micro", zero_division=0)
    f1_micro = f1_score(y_test_bin, y_pred, average="micro", zero_division=0)
    
    prec_macro = precision_score(y_test_bin, y_pred, average="macro", zero_division=0)
    rec_macro = recall_score(y_test_bin, y_pred, average="macro", zero_division=0)
    f1_macro = f1_score(y_test_bin, y_pred, average="macro", zero_division=0)
    
    prec_weighted = precision_score(y_test_bin, y_pred, average="weighted", zero_division=0)
    rec_weighted = recall_score(y_test_bin, y_pred, average="weighted", zero_division=0)
    f1_weighted = f1_score(y_test_bin, y_pred, average="weighted", zero_division=0)

    print(f"Accuracy:           {accuracy:.3f}")
    print(f"F1-micro:           {f1_micro:.3f}")
    print(f"F1-macro:           {f1_macro:.3f}")
    print(f"F1-weighted:        {f1_weighted:.3f}")
    print(f"Precision-micro:    {prec_micro:.3f}")
    print(f"Recall-micro:       {rec_micro:.3f}")

    print("\nClassification report:")
    print(classification_report(y_test_bin, y_pred, 
                                labels=actual_labels,
                                target_names=['NORM', 'PATHOLOGY'],
                                zero_division=0,
                                digits=3))

    ovr_results.append({
        "model": f"OVR_{name}",
        "accuracy": accuracy,
        "f1_micro": f1_micro,
        "f1_macro": f1_macro,
        "f1_weighted": f1_weighted,
        "prec_micro": prec_micro,
        "rec_micro": rec_micro,
        "prec_macro": prec_macro,
        "rec_macro": rec_macro,
        "num_classes": len(actual_labels)
    })

ovr_results_df = pd.DataFrame(ovr_results)
print("\nИТОГОВАЯ ТАБЛИЦА ONE-VS-REST (сортировка по F1-macro)")
print(ovr_results_df.sort_values("f1_macro", ascending=False).round(4))
# Out:
# Модель: OVR_LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.808
# F1-micro:           0.808
# F1-macro:           0.808
# F1-weighted:        0.809
# Precision-micro:    0.808
# Recall-micro:       0.808
#
# Classification report:
#               precision    recall  f1-score   support
#
#         NORM      0.750     0.844     0.794      1396
#    PATHOLOGY      0.865     0.781     0.821      1788
#
#     accuracy                          0.808      3184
#    macro avg      0.808     0.812     0.808      3184
# weighted avg      0.815     0.808     0.809      3184
#
#
# Модель: OVR_LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.803
# F1-micro:           0.803
# F1-macro:           0.802
# F1-weighted:        0.804
# Precision-micro:    0.803
# Recall-micro:       0.803
#
# Classification report:
#               precision    recall  f1-score   support
#
#         NORM      0.741     0.847     0.791      1396
#    PATHOLOGY      0.866     0.768     0.814      1788
#
#     accuracy                          0.803      3184
#    macro avg      0.803     0.808     0.802      3184
# weighted avg      0.811     0.803     0.804      3184
#
#
# Модель: OVR_SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.767
# F1-micro:           0.767
# F1-macro:           0.766
# F1-weighted:        0.768
# Precision-micro:    0.767
# Recall-micro:       0.767
#
# Classification report:
#               precision    recall  f1-score   support
#
#         NORM      0.712     0.787     0.748      1396
#    PATHOLOGY      0.819     0.752     0.784      1788
#
#     accuracy                          0.767      3184
#    macro avg      0.766     0.769     0.766      3184
# weighted avg      0.772     0.767     0.768      3184
#
#
# ИТОГОВАЯ ТАБЛИЦА ONE-VS-REST (сортировка по F1-macro)
#                         model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 0  OVR_LogisticRegression_OvR    0.8084    0.8084    0.8075       0.8091
# 1           OVR_LinearSVC_OvR    0.8031    0.8031    0.8024       0.8038
# 2        OVR_SGD_log_loss_OvR    0.7673    0.7673    0.7659       0.7681
#
#    prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 0      0.8084     0.8084      0.8076     0.8123            2
# 1      0.8031     0.8031      0.8033     0.8079            2
# 2      0.7673     0.7673      0.7656     0.7695            2

# %% [markdown]
# **Вывод**:
#
# При переходе к схеме «one vs rest» качество модели заметно улучшилось по сравнению с многоклассовой классификацией.На основе полученных результатов, лучшей моделью является OVR_LogisticRegression_OvR с наивысшими показателями по всем метрикам: accuracy 0.808, F1-macro 0.808 и F1-weighted 0.809. Модель OVR_LinearSVC_OvR показала сопоставимые результаты (accuracy 0.803), незначительно уступая логистической регрессии. Наименее эффективной оказалась модель OVR_SGD_log_loss_OvR с accuracy 0.767 В целом One vs Rest-подход даёт устойчивое и сбалансированное качество и выглядит более подходящим для данной задачи, чем классификация всех комбинаций диагнозов сразу.

# %% [markdown]
# Несмотря на хорошие метрики, бинарная постановка «NORM vs PATHOLOGY» не обеспечивает достаточной диагностической полноты: модель отвечает лишь на вопрос «есть заболевание или нет», но не позволяет различать конкретные диагнозы. Поэтому далее будем обучать отдельную бинарную модель для каждого диагноза (CD, HYP, MI, NORM, STTC и т.д.). Такой подход позволит оценивать риск каждой нозологии по отдельности и ближе к реальной клинической постановке задачи

# %% [markdown]
# # Бинарная классификация для каждого диагноза

# %%
target_cols = ["CD", "HYP", "MI", "NORM", "STTC"]

separate_results = []

for target in target_cols:
    y_train = df_train[target].astype(int).values
    y_test = df_test[target].astype(int).values
    
    print(f"\n{'='*60}")
    print(f"TARGET: {target}")
    print(f"{'='*60}")
    
 
    for name, base_model in models.items():
        print(f"\nМодель: {name}")
        
       
        model = clone(base_model)
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        actual_labels = sorted(np.unique(np.concatenate([y_train, y_test, y_pred])))
        print(f"Количество классов: {len(actual_labels)}")

        accuracy = accuracy_score(y_test, y_pred)
        
        prec_micro = precision_score(y_test, y_pred, average="micro", zero_division=0)
        rec_micro = recall_score(y_test, y_pred, average="micro", zero_division=0)
        f1_micro = f1_score(y_test, y_pred, average="micro", zero_division=0)
        
        prec_macro = precision_score(y_test, y_pred, average="macro", zero_division=0)
        rec_macro = recall_score(y_test, y_pred, average="macro", zero_division=0)
        f1_macro = f1_score(y_test, y_pred, average="macro", zero_division=0)
        
        prec_weighted = precision_score(y_test, y_pred, average="weighted", zero_division=0)
        rec_weighted = recall_score(y_test, y_pred, average="weighted", zero_division=0)
        f1_weighted = f1_score(y_test, y_pred, average="weighted", zero_division=0)

        print(f"Accuracy:           {accuracy:.3f}")
        print(f"F1-micro:           {f1_micro:.3f}")
        print(f"F1-macro:           {f1_macro:.3f}")
        print(f"F1-weighted:        {f1_weighted:.3f}")
        print(f"Precision-micro:    {prec_micro:.3f}")
        print(f"Recall-micro:       {rec_micro:.3f}")

        print("\nClassification report:")
        print(classification_report(y_test, y_pred, 
                                    labels=actual_labels,
                                    zero_division=0,
                                    digits=3))

        separate_results.append({
            "target": target,
            "model": name,
            "accuracy": accuracy,
            "f1_micro": f1_micro,
            "f1_macro": f1_macro,
            "f1_weighted": f1_weighted,
            "prec_micro": prec_micro,
            "rec_micro": rec_micro,
            "prec_macro": prec_macro,
            "rec_macro": rec_macro,
            "num_classes": len(actual_labels)
        })

separate_results_df = pd.DataFrame(separate_results)
print("\nИТОГОВАЯ ТАБЛИЦА (отдельные модели для каждого таргета)")
print(separate_results_df.sort_values("f1_macro", ascending=False).round(4))


print("\n\nРЕЗУЛЬТАТЫ ПО КАЖДОМУ ТАРГЕТУ:")
for target in target_cols:
    print(f"\n{target}:")
    print(separate_results_df[separate_results_df['target'] == target].sort_values("f1_macro", ascending=False).round(4))
# Out:
# ============================================================
# TARGET: CD
# ============================================================
#
# Модель: LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.822
# F1-micro:           0.822
# F1-macro:           0.767
# F1-weighted:        0.832
# Precision-micro:    0.822
# Recall-micro:       0.822
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.934     0.832     0.880      2503
#            1      0.560     0.786     0.654       681
#
#     accuracy                          0.822      3184
#    macro avg      0.747     0.809     0.767      3184
# weighted avg      0.854     0.822     0.832      3184
#
#
# Модель: LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.834
# F1-micro:           0.834
# F1-macro:           0.777
# F1-weighted:        0.841
# Precision-micro:    0.834
# Recall-micro:       0.834
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.931     0.852     0.890      2503
#            1      0.585     0.767     0.664       681
#
#     accuracy                          0.834      3184
#    macro avg      0.758     0.809     0.777      3184
# weighted avg      0.857     0.834     0.841      3184
#
#
# Модель: SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.809
# F1-micro:           0.809
# F1-macro:           0.747
# F1-weighted:        0.819
# Precision-micro:    0.809
# Recall-micro:       0.809
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.921     0.828     0.872      2503
#            1      0.539     0.739     0.623       681
#
#     accuracy                          0.809      3184
#    macro avg      0.730     0.783     0.747      3184
# weighted avg      0.839     0.809     0.819      3184
#
#
# ============================================================
# TARGET: HYP
# ============================================================
#
# Модель: LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.813
# F1-micro:           0.813
# F1-macro:           0.693
# F1-weighted:        0.835
# Precision-micro:    0.813
# Recall-micro:       0.813
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.953     0.826     0.885      2772
#            1      0.383     0.726     0.501       412
#
#     accuracy                          0.813      3184
#    macro avg      0.668     0.776     0.693      3184
# weighted avg      0.879     0.813     0.835      3184
#
#
# Модель: LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.837
# F1-micro:           0.837
# F1-macro:           0.708
# F1-weighted:        0.852
# Precision-micro:    0.837
# Recall-micro:       0.837
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.945     0.863     0.902      2772
#            1      0.418     0.665     0.514       412
#
#     accuracy                          0.837      3184
#    macro avg      0.682     0.764     0.708      3184
# weighted avg      0.877     0.837     0.852      3184
#
#
# Модель: SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.776
# F1-micro:           0.776
# F1-macro:           0.638
# F1-weighted:        0.803
# Precision-micro:    0.776
# Recall-micro:       0.776
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.933     0.800     0.861      2772
#            1      0.313     0.612     0.414       412
#
#     accuracy                          0.776      3184
#    macro avg      0.623     0.706     0.638      3184
# weighted avg      0.852     0.776     0.803      3184
#
#
# ============================================================
# TARGET: MI
# ============================================================
#
# Модель: LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.761
# F1-micro:           0.761
# F1-macro:           0.721
# F1-weighted:        0.774
# Precision-micro:    0.761
# Recall-micro:       0.761
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.905     0.760     0.826      2382
#            1      0.517     0.763     0.617       802
#
#     accuracy                          0.761      3184
#    macro avg      0.711     0.762     0.721      3184
# weighted avg      0.807     0.761     0.774      3184
#
#
# Модель: LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.774
# F1-micro:           0.774
# F1-macro:           0.730
# F1-weighted:        0.784
# Precision-micro:    0.774
# Recall-micro:       0.774
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.898     0.787     0.839      2382
#            1      0.538     0.736     0.621       802
#
#     accuracy                          0.774      3184
#    macro avg      0.718     0.761     0.730      3184
# weighted avg      0.808     0.774     0.784      3184
#
#
# Модель: SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.740
# F1-micro:           0.740
# F1-macro:           0.691
# F1-weighted:        0.752
# Precision-micro:    0.740
# Recall-micro:       0.740
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.875     0.761     0.814      2382
#            1      0.489     0.678     0.568       802
#
#     accuracy                          0.740      3184
#    macro avg      0.682     0.720     0.691      3184
# weighted avg      0.778     0.740     0.752      3184
#
#
# ============================================================
# TARGET: NORM
# ============================================================
#
# Модель: LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.808
# F1-micro:           0.808
# F1-macro:           0.808
# F1-weighted:        0.809
# Precision-micro:    0.808
# Recall-micro:       0.808
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.865     0.781     0.821      1788
#            1      0.750     0.844     0.794      1396
#
#     accuracy                          0.808      3184
#    macro avg      0.808     0.812     0.808      3184
# weighted avg      0.815     0.808     0.809      3184
#
#
# Модель: LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.807
# F1-micro:           0.807
# F1-macro:           0.806
# F1-weighted:        0.807
# Precision-micro:    0.807
# Recall-micro:       0.807
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.864     0.778     0.819      1788
#            1      0.748     0.843     0.793      1396
#
#     accuracy                          0.807      3184
#    macro avg      0.806     0.811     0.806      3184
# weighted avg      0.813     0.807     0.807      3184
#
#
# Модель: SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.767
# F1-micro:           0.767
# F1-macro:           0.766
# F1-weighted:        0.768
# Precision-micro:    0.767
# Recall-micro:       0.767
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.819     0.752     0.784      1788
#            1      0.712     0.787     0.748      1396
#
#     accuracy                          0.767      3184
#    macro avg      0.766     0.769     0.766      3184
# weighted avg      0.772     0.767     0.768      3184
#
#
# ============================================================
# TARGET: STTC
# ============================================================
#
# Модель: LogisticRegression_OvR
# Количество классов: 2
# Accuracy:           0.774
# F1-micro:           0.774
# F1-macro:           0.738
# F1-weighted:        0.787
# Precision-micro:    0.774
# Recall-micro:       0.774
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.921     0.765     0.836      2391
#            1      0.531     0.803     0.640       793
#
#     accuracy                          0.774      3184
#    macro avg      0.726     0.784     0.738      3184
# weighted avg      0.824     0.774     0.787      3184
#
#
# Модель: LinearSVC_OvR
# Количество классов: 2
# Accuracy:           0.781
# F1-micro:           0.781
# F1-macro:           0.744
# F1-weighted:        0.793
# Precision-micro:    0.781
# Recall-micro:       0.781
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.924     0.772     0.841      2391
#            1      0.540     0.808     0.647       793
#
#     accuracy                          0.781      3184
#    macro avg      0.732     0.790     0.744      3184
# weighted avg      0.828     0.781     0.793      3184
#
#
# Модель: SGD_log_loss_OvR
# Количество классов: 2
# Accuracy:           0.716
# F1-micro:           0.716
# F1-macro:           0.676
# F1-weighted:        0.733
# Precision-micro:    0.716
# Recall-micro:       0.716
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0      0.888     0.712     0.790      2391
#            1      0.457     0.729     0.561       793
#
#     accuracy                          0.716      3184
#    macro avg      0.672     0.721     0.676      3184
# weighted avg      0.780     0.716     0.733      3184
#
#
# ИТОГОВАЯ ТАБЛИЦА (отдельные модели для каждого таргета)
#    target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 9    NORM  LogisticRegression_OvR    0.8084    0.8084    0.8075       0.8091
# 10   NORM           LinearSVC_OvR    0.8065    0.8065    0.8057       0.8073
# 1      CD           LinearSVC_OvR    0.8339    0.8339    0.7767       0.8413
# 0      CD  LogisticRegression_OvR    0.8219    0.8219    0.7669       0.8317
# 11   NORM        SGD_log_loss_OvR    0.7673    0.7673    0.7659       0.7681
# 2      CD        SGD_log_loss_OvR    0.8087    0.8087    0.7474       0.8186
# 13   STTC           LinearSVC_OvR    0.7808    0.7808    0.7442       0.7927
# 12   STTC  LogisticRegression_OvR    0.7745    0.7745    0.7377       0.7870
# 7      MI           LinearSVC_OvR    0.7742    0.7742    0.7302       0.7843
# 6      MI  LogisticRegression_OvR    0.7610    0.7610    0.7215       0.7735
# 4     HYP           LinearSVC_OvR    0.8370    0.8370    0.7078       0.8518
# 3     HYP  LogisticRegression_OvR    0.8131    0.8131    0.6931       0.8354
# 8      MI        SGD_log_loss_OvR    0.7403    0.7403    0.6912       0.7523
# 14   STTC        SGD_log_loss_OvR    0.7164    0.7164    0.6759       0.7334
# 5     HYP        SGD_log_loss_OvR    0.7758    0.7758    0.6376       0.8034
#
#     prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 9       0.8084     0.8084      0.8076     0.8123            2
# 10      0.8065     0.8065      0.8059     0.8105            2
# 1       0.8339     0.8339      0.7579     0.8093            2
# 0       0.8219     0.8219      0.7470     0.8087            2
# 11      0.7673     0.7673      0.7656     0.7695            2
# 2       0.8087     0.8087      0.7297     0.7832            2
# 13      0.7808     0.7808      0.7320     0.7900            2
# 12      0.7745     0.7745      0.7263     0.7841            2
# 7       0.7742     0.7742      0.7181     0.7614            2
# 6       0.7610     0.7610      0.7112     0.7617            2
# 4       0.8370     0.8370      0.6819     0.7638            2
# 3       0.8131     0.8131      0.6679     0.7759            2
# 8       0.7403     0.7403      0.6821     0.7197            2
# 14      0.7164     0.7164      0.6722     0.7206            2
# 5       0.7758     0.7758      0.6227     0.7059            2
#
#
# РЕЗУЛЬТАТЫ ПО КАЖДОМУ ТАРГЕТУ:
#
# CD:
#   target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 1     CD           LinearSVC_OvR    0.8339    0.8339    0.7767       0.8413
# 0     CD  LogisticRegression_OvR    0.8219    0.8219    0.7669       0.8317
# 2     CD        SGD_log_loss_OvR    0.8087    0.8087    0.7474       0.8186
#
#    prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 1      0.8339     0.8339      0.7579     0.8093            2
# 0      0.8219     0.8219      0.7470     0.8087            2
# 2      0.8087     0.8087      0.7297     0.7832            2
#
# HYP:
#   target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 4    HYP           LinearSVC_OvR    0.8370    0.8370    0.7078       0.8518
# 3    HYP  LogisticRegression_OvR    0.8131    0.8131    0.6931       0.8354
# 5    HYP        SGD_log_loss_OvR    0.7758    0.7758    0.6376       0.8034
#
#    prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 4      0.8370     0.8370      0.6819     0.7638            2
# 3      0.8131     0.8131      0.6679     0.7759            2
# 5      0.7758     0.7758      0.6227     0.7059            2
#
# MI:
#   target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 7     MI           LinearSVC_OvR    0.7742    0.7742    0.7302       0.7843
# 6     MI  LogisticRegression_OvR    0.7610    0.7610    0.7215       0.7735
# 8     MI        SGD_log_loss_OvR    0.7403    0.7403    0.6912       0.7523
#
#    prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 7      0.7742     0.7742      0.7181     0.7614            2
# 6      0.7610     0.7610      0.7112     0.7617            2
# 8      0.7403     0.7403      0.6821     0.7197            2
#
# NORM:
#    target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 9    NORM  LogisticRegression_OvR    0.8084    0.8084    0.8075       0.8091
# 10   NORM           LinearSVC_OvR    0.8065    0.8065    0.8057       0.8073
# 11   NORM        SGD_log_loss_OvR    0.7673    0.7673    0.7659       0.7681
#
#     prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 9       0.8084     0.8084      0.8076     0.8123            2
# 10      0.8065     0.8065      0.8059     0.8105            2
# 11      0.7673     0.7673      0.7656     0.7695            2
#
# STTC:
#    target                   model  accuracy  f1_micro  f1_macro  f1_weighted  \
# 13   STTC           LinearSVC_OvR    0.7808    0.7808    0.7442       0.7927
# 12   STTC  LogisticRegression_OvR    0.7745    0.7745    0.7377       0.7870
# 14   STTC        SGD_log_loss_OvR    0.7164    0.7164    0.6759       0.7334
#
#     prec_micro  rec_micro  prec_macro  rec_macro  num_classes
# 13      0.7808     0.7808      0.7320     0.7900            2
# 12      0.7745     0.7745      0.7263     0.7841            2
# 14      0.7164     0.7164      0.6722     0.7206            2

# %% [markdown]
# **Вывод**:
#
# Каждая модель решает: "Есть ли у пациента данный диагноз?" (да/нет)
#
# С помощью такого подхода мы избегаем проблемы с дисбалансом комбинированных классов.
# Но распределение отдельных диагнозов все еще остаётся заметно несбалансированным.
#
# На основе полученных результатов при обучении отдельных моделей для каждого диагноза, LinearSVC_OvR демонстрирует наилучшую производительность, побеждая по F1-macro в 4 из 5 таргетов (CD, HYP, MI, STTC) с показателями от 0.708 до 0.777. Для таргета NORM лучшей оказалась LogisticRegression_OvR с F1-macro 0.808, незначительно опережая LinearSVC (0.806). Наиболее сложными для классификации оказались таргеты HYP (F1-macro 0.708 у лучшей модели) и MI (0.730), что связано с сильным дисбалансом классов, в то время как NORM и CD показали наилучшие результаты с accuracy выше 0.83. Модель SGD_log_loss_OvR стабильно уступает конкурентам на всех таргетах, показывая результаты на 3-6% ниже других моделей.
#
# Таким образом, стратегия обучения отдельных моделей на каждый диагноз является перспективным направлением для медицинской диагностики по данным ЭКГ, однако требует дополнительной оптимизации.
#
#  Для нашей задачи  наиболее релевантной метрикой является F1-macro. Эта метрика усредняет F1-score по всем классам с равными весами, что критично важно при наличии дисбаланса классов.
